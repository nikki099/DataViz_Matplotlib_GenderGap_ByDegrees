# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
#chapter 1 Introduction

# %%
pd.set_option('display.width',1000)

# %%
recent_grads=pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[1,:]
# Out:
# Rank                                                 2
# Major_code                                        2416
# Major                   MINING AND MINERAL ENGINEERING
# Total                                              756
# Men                                                679
# Women                                               77
# Major_category                             Engineering
# ShareWomen                                    0.101852
# Sample_size                                          7
# Employed                                           640
# Full_time                                          556
# Part_time                                          170
# Full_time_year_round                               388
# Unemployed                                          85
# Unemployment_rate                             0.117241
# Median                                           75000
# P25th                                            55000
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women            Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0    Biology & Life Science    0.637293           47      6259      ...             2190                  3602         304           0.046320   26000  20000  39000          2771              2947            743
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0  Psychology & Social Work    0.817099            7      2125      ...              572                  1211         148           0.065112   25000  24000  34000          1488               615             82
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  ShareWomen  Sample_size       Employed      Full_time      Part_time  Full_time_year_round    Unemployed  Unemployment_rate         Median         P25th          P75th   College_jobs  Non_college_jobs  Low_wage_jobs
# count  173.000000   173.000000     172.000000     172.000000     172.000000  172.000000   173.000000     173.000000     173.000000     173.000000            173.000000    173.000000         173.000000     173.000000    173.000000     173.000000     173.000000        173.000000     173.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419    0.522223   356.080925   31192.763006   26029.306358    8832.398844          19694.427746   2416.329480           0.068191   40151.445087  29501.445087   51494.219653   12322.635838      13284.497110    3859.017341
# ...

# %%
raw_data_count=recent_grads.shape[0] #173

# %%
recent_grads=recent_grads.dropna(how='any')
cleaned_data_count=recent_grads.shape[0]

# %%
print(cleaned_data_count)
# Out:
# 172

# %%
#chapter 2 df and scatter plot

# %%
#Scatterplot - Sample_size and Median

ax=recent_grads.plot(x='Sample_size', y='Median', kind='scatter', 
                  title='Median vs. Sample_size', figsize=(5,10))

ax.set_xlim(0,5000)
# Out:
# (0, 5000)

# %%
#Scatterplot - Sample_size and Unemployment_Rate

ax=recent_grads.plot(x='Sample_size', y='Unemployment_rate',
                  kind='scatter', title='Sample_size vs Unemployment_Rate',
                  figsize=(5,10))

ax.set_xlim(0,5000)
# Out:
# (0, 5000)

# %%
#Scatterplot -Fulltime and Median

ax=recent_grads.plot(x='Full_time', y='Median',
                  kind='scatter', title='Fulltime and Median',
                  figsize=(5,10))

ax.set_xlim(0,300000)
# Out:
# (0, 300000)

# %%
#Scatterplot - ShareWomen and Unemployment_Rate

ax=recent_grads.plot(x='ShareWomen', y='Unemployment_rate',
                  kind='scatter', title='Sample_size vs Unemployment_Rate',
                  figsize=(5,10))

ax.set_xlim(0,1.2)
# Out:
# (0, 1.2)

# %%
#Scatterplot - Men vs Median

ax=recent_grads.plot(x='Men', y='Median',
                  kind='scatter', title='Men vs Median',
                  figsize=(5,10))

ax.set_xlim(0,200000)
# Out:
# (0, 200000)

# %%
#Scatterplot - Women vs Median

ax=recent_grads.plot(x='Women', y='Median',
                  kind='scatter', title='Men vs Median',
                  figsize=(5,10))

ax.set_xlim(0,200000)
# Out:
# (0, 200000)

# %%
#Do students in more popular majors make more money?
#Answer - yes

ax=recent_grads.plot(x='Rank', y='Median', kind='Scatter', figsize=(5,10))
ax.set_title("Do students in more popular majors make more money?")
ax.set_xlim(0,200)
# Out:
# (0, 200)

# %%
#Do students that majored in subjects that were majority female make more money?
#Answer yes

ax=recent_grads.plot(x='ShareWomen', y='Median',
                     title="Do students majored in subs that were majority women make more money",
                     kind='scatter',
                     figsize=(5,10))
ax.set_xlim(0,1.2)
# Out:
# (0, 1.2)

# %%
#Is there any link between the number of full-time employees and median salary?
#Yes, but weak.

ax=recent_grads.plot(x='Full_time', y='Median',
                     kind='scatter',
                     title="Fulltime vs Meidan Salary",
                     figsize=(5,10)                                 
                    )

ax.set_xlim(0,300000)
# Out:
# (0, 300000)

# %%
#chapter 3 df and histgram

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=10)

# %%
recent_grads['Employed'].hist(bins=10)

# %%
recent_grads['Full_time'].hist(bins=10, range=(0,260000))

# %%
recent_grads['ShareWomen'].hist(bins=10, range=(0,0.9))

# %%
recent_grads['Unemployment_rate'].hist(bins=20, range=(0,1))

# %%
recent_grads['Men'].hist(bins=20, range=(0,200000))

# %%
recent_grads['Women'].hist(bins=20, range=(0,200000))

# %%
#What percent of majors are predominantly male? Predominantly female?

ax=recent_grads.plot(
    x='Major',
    y='ShareWomen',
    kind='hist',
    figsize=(10,10)
)

# %%
#What's the most common median salary range?
#Answer=40K
recent_grads['Median'].hist(bins=10, range=(0,110000))

# %%
# chapter 4 -  df and scatter matrix

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3da3789518>,
# ...
#       dtype=object)

# %%
#chapter 5 df and bar plot

# %%
first10=recent_grads[:10]
first10.plot.barh(x='Major', y='ShareWomen',figsize=(10,7))

# %%
last10=recent_grads[-10:]
last10.plot.barh(x='Major', y='ShareWomen',figsize=(10,7))

# %%
first10.plot.barh(x='Major', y='Unemployment_rate')

# %%
last10.plot.barh(x='Major', y='Unemployment_rate')
